# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.metrics.cluster import adjusted_rand_score, rand_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import rbf_kernel
from time import time
import networkx as nx

# import warnings filter
from warnings import simplefilter
# ignore all future warnings

# %%
def get_data():
    data = np.loadtxt('./semeion.data', dtype=np.int8)
    return data[:, :256], data[:, 256:]


def one_hot_decode(y: np.array):
    return np.argmax(y, axis=1)


def get_data_transformed():
    data = np.loadtxt('./semeion.data', dtype=np.int8)
    return data[:, :256], one_hot_decode(data[:, 256:])

# %%
class NoDR:
    def __init__(self, n_components):
        pass
    def fit_transform(self, X):
        return X.copy()

# %%
simplefilter(action='ignore', category=FutureWarning)
ks = range(5,16)
ds = (2,64,128, 256)

# %%
def plotimg(row: np.array):
    img = row.reshape((16,16))
    plt.imshow(img)
    plt.show()

# %%
def plot2D(X, y, title):
    'Plot first 2 columns and color according to labels'
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.title(title)
    plt.show()
    plt.clf()

# %%
def print_rand(y_true, y_pred):
    'Print and return the Rand Indexes'
    ari = adjusted_rand_score(y_true, y_pred)
    ri = rand_score(y_true, y_pred)
    print('adjusted_rand_score', round(ari * 100, 2), '%')
    print('rand_score', round(ri * 100, 2), '%', end='\n\n')
    return ari, ri

# %%
class N_Cut():
    def __init__(self, n_clusters):
        self.n_clusters = n_clusters


    def __str__(self):
        return 'NCUT'


    def fit(self, X, verbose=False):
        self.n_samples, self.n_features = X.shape

        A = rbf_kernel(X)

        np.fill_diagonal(A, 0.0)

        G = nx.from_numpy_matrix(A)
        L = nx.normalized_laplacian_matrix(G)
        w = np.linalg.eigvals(L.A)
        if verbose:
         print("Largest eigenvalue:", max(w))
         print("Smallest eigenvalue:", min(w))
         print(f"first k={self.n_clusters} nonzero eigenvalues:", w[1:self.n_clusters+1])

        w, v = np.linalg.eig(L.A)

        if not abs(w[0]) < 1e-10:
            raise ValueError(f'First eigenvalue is {w[0]}.\nMust be close to zero.')

        U = v[:, 1:self.n_clusters+1]

        kmeans = KMeans(n_clusters=self.n_clusters).fit(U)

        self.labels_ = kmeans.labels_

# %%
def NCut_Result(p=False):

    columns = ('clustering_model', 'dim_red_model', 'd', 'k', 'time', 'ARI', 'RI')
    rows = []

    X, y = get_data_transformed()
    for k in ks:
        for d in ds:
            if d != 256:
                embedding_model = PCA
            else:
                embedding_model = NoDR
            start_time = time()
            embedding = embedding_model(n_components=d)  # DR model
            X_transformed = embedding.fit_transform(X)
            model = N_Cut(k)  # clustering model
            model.fit(X_transformed)
            elapsed = time() - start_time
            title = f'Results for {model} on {d}-{embedding_model.__name__} - k={k} ({elapsed:.02f}s)'
            print(title)
            ari, ri = print_rand(y, model.labels_)
            if p: plot2D(X_transformed, model.labels_, title)
            result = (str(model), embedding_model.__name__, d, k, elapsed, ari, ri)
            rows.append(result)
    df = pd.DataFrame(data=rows, columns=columns)
    print(df)
    df.to_csv('NCut.csv', index=False)

# %%
def results_analysis():
    df = pd.read_csv('NCut.csv')

    dfg_k = df.groupby('k').mean()[['time','ARI','RI']]
    print('averages by number of cluster:')
    print(dfg_k.sort_values('ARI', ascending=False))
    print()

    dfg_dr = df.groupby('dim_red_model').mean()[['time','ARI','RI']]
    print('averages by DR model:')
    print(dfg_dr.sort_values('ARI', ascending=False))
    print()


    print('best ARI achieved by:')
    print(df.sort_values('ARI', ascending=False).head(3))

# %%
def main():

    NCut_Result()
    results_analysis()

# %%
if __name__ == '__main__':
    main()
# Out:
# Results for NCUT on 2-PCA - k=5 (13.86s)
# adjusted_rand_score 19.9 %
# rand_score 76.78 %
#
# Results for NCUT on 64-PCA - k=5 (12.65s)
# adjusted_rand_score 24.25 %
# rand_score 79.8 %
#
# Results for NCUT on 128-PCA - k=5 (12.15s)
# adjusted_rand_score 23.75 %
# rand_score 79.68 %
#
# Results for NCUT on 256-NoDR - k=5 (12.02s)
# adjusted_rand_score 23.66 %
# rand_score 79.67 %
#
# Results for NCUT on 2-PCA - k=6 (12.14s)
# adjusted_rand_score 21.37 %
# rand_score 79.51 %
#
# Results for NCUT on 64-PCA - k=6 (12.31s)
# adjusted_rand_score 28.71 %
# rand_score 82.64 %
#
# Results for NCUT on 128-PCA - k=6 (12.62s)
# adjusted_rand_score 30.27 %
# rand_score 83.33 %
#
# Results for NCUT on 256-NoDR - k=6 (11.93s)
# adjusted_rand_score 29.63 %
# rand_score 83.23 %
#
# Results for NCUT on 2-PCA - k=7 (12.06s)
# adjusted_rand_score 19.64 %
# rand_score 78.99 %
#
# Results for NCUT on 64-PCA - k=7 (12.05s)
# adjusted_rand_score 33.28 %
# rand_score 85.33 %
#
# Results for NCUT on 128-PCA - k=7 (11.90s)
# adjusted_rand_score 33.31 %
# rand_score 85.36 %
#
# Results for NCUT on 256-NoDR - k=7 (11.86s)
# adjusted_rand_score 34.56 %
# rand_score 85.6 %
#
# Results for NCUT on 2-PCA - k=8 (12.41s)
# adjusted_rand_score 21.42 %
# rand_score 82.51 %
#
# Results for NCUT on 64-PCA - k=8 (12.22s)
# adjusted_rand_score 37.02 %
# rand_score 86.92 %
#
# Results for NCUT on 128-PCA - k=8 (12.22s)
# adjusted_rand_score 35.62 %
# rand_score 86.64 %
#
# Results for NCUT on 256-NoDR - k=8 (12.08s)
# adjusted_rand_score 36.68 %
# rand_score 86.95 %
#
# Results for NCUT on 2-PCA - k=9 (12.32s)
# adjusted_rand_score 19.01 %
# rand_score 83.3 %
#
# Results for NCUT on 64-PCA - k=9 (11.90s)
# adjusted_rand_score 34.79 %
# rand_score 87.35 %
#
# Results for NCUT on 128-PCA - k=9 (12.04s)
# adjusted_rand_score 29.3 %
# rand_score 86.55 %
#
# Results for NCUT on 256-NoDR - k=9 (12.00s)
# adjusted_rand_score 35.68 %
# rand_score 87.64 %
#
# Results for NCUT on 2-PCA - k=10 (12.41s)
# adjusted_rand_score 20.06 %
# rand_score 83.1 %
#
# Results for NCUT on 64-PCA - k=10 (12.13s)
# adjusted_rand_score 33.63 %
# rand_score 87.69 %
#
# Results for NCUT on 128-PCA - k=10 (11.96s)
# adjusted_rand_score 34.2 %
# rand_score 87.85 %
#
# Results for NCUT on 256-NoDR - k=10 (11.97s)
# adjusted_rand_score 33.77 %
# rand_score 87.99 %
#
# Results for NCUT on 2-PCA - k=11 (12.09s)
# adjusted_rand_score 19.19 %
# rand_score 84.31 %
#
# Results for NCUT on 64-PCA - k=11 (12.30s)
# adjusted_rand_score 32.74 %
# rand_score 88.14 %
#
# Results for NCUT on 128-PCA - k=11 (11.98s)
# adjusted_rand_score 29.49 %
# rand_score 87.77 %
#
# Results for NCUT on 256-NoDR - k=11 (13.64s)
# adjusted_rand_score 36.5 %
# rand_score 88.83 %
#
# Results for NCUT on 2-PCA - k=12 (14.13s)
# adjusted_rand_score 20.6 %
# rand_score 84.7 %
#
# Results for NCUT on 64-PCA - k=12 (14.21s)
# adjusted_rand_score 35.69 %
# rand_score 88.92 %
#
# Results for NCUT on 128-PCA - k=12 (13.56s)
# adjusted_rand_score 31.49 %
# rand_score 88.37 %
#
# Results for NCUT on 256-NoDR - k=12 (13.00s)
# adjusted_rand_score 30.83 %
# rand_score 88.38 %
#
# Results for NCUT on 2-PCA - k=13 (12.55s)
# adjusted_rand_score 18.76 %
# rand_score 85.29 %
#
# Results for NCUT on 64-PCA - k=13 (13.06s)
# adjusted_rand_score 36.63 %
# rand_score 89.51 %
#
# Results for NCUT on 128-PCA - k=13 (12.44s)
# adjusted_rand_score 31.88 %
# rand_score 88.84 %
#
# Results for NCUT on 256-NoDR - k=13 (12.95s)
# adjusted_rand_score 33.79 %
# rand_score 89.27 %
#
# Results for NCUT on 2-PCA - k=14 (12.69s)
# adjusted_rand_score 18.25 %
# rand_score 85.81 %
#
# Results for NCUT on 64-PCA - k=14 (12.69s)
# adjusted_rand_score 35.74 %
# rand_score 89.83 %
#
# Results for NCUT on 128-PCA - k=14 (13.09s)
# adjusted_rand_score 34.19 %
# rand_score 89.58 %
#
# Results for NCUT on 256-NoDR - k=14 (13.08s)
# adjusted_rand_score 33.47 %
# rand_score 89.49 %
#
# Results for NCUT on 2-PCA - k=15 (13.34s)
# adjusted_rand_score 17.93 %
# rand_score 86.06 %
#
# Results for NCUT on 64-PCA - k=15 (12.39s)
# adjusted_rand_score 34.33 %
# rand_score 89.86 %
#
# Results for NCUT on 128-PCA - k=15 (12.38s)
# adjusted_rand_score 32.56 %
# rand_score 89.55 %
#
# Results for NCUT on 256-NoDR - k=15 (12.61s)
# adjusted_rand_score 33.16 %
# rand_score 89.65 %
#
#    clustering_model dim_red_model    d   k       time       ARI        RI
# 0              NCUT           PCA    2   5  13.864685  0.199028  0.767762
# 1              NCUT           PCA   64   5  12.649546  0.242466  0.797952
# 2              NCUT           PCA  128   5  12.151481  0.237510  0.796779
# 3              NCUT          NoDR  256   5  12.018857  0.236645  0.796717
# 4              NCUT           PCA    2   6  12.137772  0.213673  0.795057
# 5              NCUT           PCA   64   6  12.311077  0.287075  0.826352
# 6              NCUT           PCA  128   6  12.623976  0.302717  0.833327
# 7              NCUT          NoDR  256   6  11.930096  0.296321  0.832270
# 8              NCUT           PCA    2   7  12.056757  0.196427  0.789850
# 9              NCUT           PCA   64   7  12.052766  0.332831  0.853275
# 10             NCUT           PCA  128   7  11.903321  0.333116  0.853612
# 11             NCUT          NoDR  256   7  11.855295  0.345580  0.855968
# 12             NCUT           PCA    2   8  12.412082  0.214157  0.825093
# 13             NCUT           PCA   64   8  12.216820  0.370219  0.869161
# 14             NCUT           PCA  128   8  12.219285  0.356182  0.866370
# 15             NCUT          NoDR  256   8  12.084681  0.366834  0.869493
# 16             NCUT           PCA    2   9  12.319028  0.190103  0.832990
# 17             NCUT           PCA   64   9  11.895190  0.347881  0.873466
# 18             NCUT           PCA  128   9  12.042794  0.293015  0.865515
# 19             NCUT          NoDR  256   9  11.998960  0.356792  0.876436
# 20             NCUT           PCA    2  10  12.412806  0.200573  0.830980
# 21             NCUT           PCA   64  10  12.134358  0.336301  0.876912
# 22             NCUT           PCA  128  10  11.960045  0.341982  0.878455
# 23             NCUT          NoDR  256  10  11.970470  0.337744  0.879858
# 24             NCUT           PCA    2  11  12.087674  0.191930  0.843083
# 25             NCUT           PCA   64  11  12.299681  0.327393  0.881370
# 26             NCUT           PCA  128  11  11.979205  0.294857  0.877650
# 27             NCUT          NoDR  256  11  13.644511  0.364965  0.888283
# 28             NCUT           PCA    2  12  14.133188  0.206013  0.847036
# 29             NCUT           PCA   64  12  14.206896  0.356897  0.889239
# 30             NCUT           PCA  128  12  13.555822  0.314877  0.883678
# 31             NCUT          NoDR  256  12  13.001232  0.308342  0.883836
# 32             NCUT           PCA    2  13  12.549751  0.187552  0.852909
# 33             NCUT           PCA   64  13  13.061071  0.366277  0.895123
# 34             NCUT           PCA  128  13  12.440696  0.318798  0.888448
# 35             NCUT          NoDR  256  13  12.945152  0.337868  0.892718
# 36             NCUT           PCA    2  14  12.685079  0.182451  0.858124
# 37             NCUT           PCA   64  14  12.694050  0.357432  0.898257
# 38             NCUT           PCA  128  14  13.089947  0.341937  0.895827
# 39             NCUT          NoDR  256  14  13.076824  0.334667  0.894904
# 40             NCUT           PCA    2  15  13.340178  0.179252  0.860609
# 41             NCUT           PCA   64  15  12.389898  0.343292  0.898642
# 42             NCUT           PCA  128  15  12.382390  0.325645  0.895513
# 43             NCUT          NoDR  256  15  12.610276  0.331618  0.896514
# averages by number of cluster:
#          time       ARI        RI
# k
# 8   12.233217  0.326848  0.857529
# 10  12.119420  0.304150  0.866551
# 14  12.886475  0.304122  0.886778
# 13  12.749168  0.302624  0.882300
# 7   11.967035  0.301988  0.838176
# 9   12.063993  0.296948  0.862102
# 12  13.724284  0.296532  0.875947
# 15  12.680686  0.294952  0.887819
# 11  12.502768  0.294786  0.872597
# 6   12.250730  0.274947  0.821752
# 5   12.671142  0.228912  0.789803
#
# averages by DR model:
#                     time       ARI        RI
# dim_red_model
# NoDR           12.466941  0.328852  0.869727
# PCA            12.553313  0.281511  0.854497
#
# best ARI achieved by:
#    clustering_model dim_red_model    d   k       time       ARI        RI
# 13             NCUT           PCA   64   8  12.216820  0.370219  0.869161
# 15             NCUT          NoDR  256   8  12.084681  0.366834  0.869493
# 33             NCUT           PCA   64  13  13.061071  0.366277  0.895123
